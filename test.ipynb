# %% [markdown]
# <a href="https://colab.research.google.com/github/kapoor1309/BH-25/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import torch
from PIL import Image
import numpy as np
import cv2
from torchvision import models, transforms
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
import torch.nn as nn

# %%
class MultiTaskModel(nn.Module):
    def __init__(self, num_triplets, num_tools, num_verbs, num_targets):
        super(MultiTaskModel, self).__init__()
        self.backbone = models.resnet50(pretrained=True)
        self.backbone.fc = nn.Identity()
        backbone_output_dim = 2048

        self.triplet_head = nn.Linear(backbone_output_dim, num_triplets)
        self.tool_head = nn.Linear(backbone_output_dim, num_tools)
        self.verb_head = nn.Linear(backbone_output_dim, num_verbs)
        self.target_head = nn.Linear(backbone_output_dim, num_targets)

    def forward(self, x):
        features = self.backbone(x)
        triplet_preds = self.triplet_head(features)
        tool_preds = self.tool_head(features)
        verb_preds = self.verb_head(features)
        target_preds = self.target_head(features)
        return triplet_preds, tool_preds, verb_preds, target_preds

def process_single_image(image_path, model_1, model_2, transform, cam_extractor, device, frame_id):
    """Process a single image and return formatted predictions"""
    print(f"\nProcessing frame: {frame_id}")

    image = Image.open(image_path).convert("RGB")
    original_image = np.array(image)

    # Get frame-level predictions (recognition)
    input_tensor = transform(image).unsqueeze(0).to(device)
    with torch.no_grad():
        triplet_preds, _, _, _ = model_2(input_tensor)
    recognition_probs = torch.sigmoid(triplet_preds).cpu().numpy()[0].tolist()

    # Generate CAM for detection
    grayscale_cam = cam_extractor(input_tensor=input_tensor, targets=[ClassifierOutputTarget(0)])
    cam = grayscale_cam[0]
    cam_resized = cv2.resize(cam, (original_image.shape[1], original_image.shape[0]))

    # Generate bounding boxes
    threshold = 0.5
    binary_mask = (cam_resized >= threshold).astype(np.uint8) * 255
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Process each detected region
    detections = []
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)

        # Process cropped region
        cropped_image = original_image[y:y+h, x:x+w]
        if cropped_image.size == 0:
            continue

        cropped_pil = Image.fromarray(cropped_image)
        transformed_image = transform(cropped_pil).unsqueeze(0).to(device)

        with torch.no_grad():
            triplet_preds, tool_preds, _, _ = model_2(transformed_image)

        # Get highest probability triplet and tool
        triplet_probs = torch.sigmoid(triplet_preds).cpu().numpy()[0]
        tool_probs = torch.sigmoid(tool_preds).cpu().numpy()[0]

        triplet_id = int(np.argmax(triplet_probs))
        tool_id = int(np.argmax(tool_probs))
        tool_prob = float(tool_probs[tool_id])

        detection = {
            "triplet": triplet_id,
            "instrument": [tool_id, tool_prob, x, y, w, h]
        }
        detections.append(detection)

    frame_results = {
        "recognition": recognition_probs,
        "detection": detections
    }

    # Print progress
    print(f"Completed frame {frame_id} - Found {len(detections)} detections")

    return frame_results

def process_video_folder(video_folder, model_1, model_2, transform, cam_extractor, device):
    """Process all frames in a video folder"""
    video_folder_name = os.path.basename(video_folder)
    print(f"\nProcessing {video_folder_name}")
    video_predictions = {}

    image_files = [f for f in os.listdir(video_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    image_files.sort()
    total_frames = len(image_files)

    print(f"Found {total_frames} frames in {video_folder_name}")

    for idx, image_file in enumerate(image_files, 1):
        frame_id = os.path.splitext(image_file)[0]
        image_path = os.path.join(video_folder, image_file)

        try:
            frame_results = process_single_image(
                image_path, model_1, model_2, transform, cam_extractor, device, frame_id
            )
            video_predictions[frame_id] = frame_results
            print(f"Progress: {idx}/{total_frames} frames processed in {video_folder_name}")
        except Exception as e:
            print(f"Error processing {image_file}: {str(e)}")
            continue

    return video_predictions

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    base_dir = "/content/CholecT50/videos"
    video_ids = ["VID92", "VID96", "VID103", "VID110", "VID111"]

    transform = transforms.Compose([
        transforms.Resize((256, 448)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    print("Loading models...")
    # Task 1 model
    model_1 = models.resnet50(pretrained=True)
    model_1.fc = torch.nn.Linear(model_1.fc.in_features, 6)
    model_1.load_state_dict(torch.load("/content/trained_model_fold_.pth"))
    model_1 = model_1.to(device)
    model_1.eval()

    # Task 2 model
    model_2 = MultiTaskModel(num_triplets=100, num_tools=6, num_verbs=10, num_targets=15)
    model_2.load_state_dict(torch.load("/content/multi_task_model.pth", map_location=device))
    model_2 = model_2.to(device)
    model_2.eval()

    # Initialize GradCAM
    cam_extractor = GradCAM(model=model_1, target_layers=[model_1.layer4[-1]])

    # Process all video folders
    all_predictions = {}
    for video_id in video_ids:
        video_folder_path = os.path.join(base_dir, video_id)
        if not os.path.exists(video_folder_path):
            print(f"Warning: {video_id} not found, skipping...")
            continue

        video_predictions = process_video_folder(
            video_folder_path, model_1, model_2, transform, cam_extractor, device
        )
        all_predictions[video_id] = video_predictions

    # Save results
    output_file = os.path.join(base_dir, 'all_video_predictions.json')
    with open(output_file, 'w') as f:
        json.dump(all_predictions, f)

    print(f"\nProcessing complete! Results saved to: {output_file}")

if __name__ == "__main__":
    main()
# Out:
# Loading models...
# <ipython-input-5-7c2014fa4f54>:138: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_1.load_state_dict(torch.load("/content/trained_model_fold_.pth"))
# <ipython-input-5-7c2014fa4f54>:144: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_2.load_state_dict(torch.load("/content/multi_task_model.pth", map_location=device))
# Streaming output truncated to the last 5000 lines.
# Completed frame 000896 - Found 4 detections
# Progress: 897/2146 frames processed in VID111
#
# Processing frame: 000897
# Completed frame 000897 - Found 4 detections
# Progress: 898/2146 frames processed in VID111
#
# Processing frame: 000898
# Completed frame 000898 - Found 3 detections
# Progress: 899/2146 frames processed in VID111
#
# Processing frame: 000899
# Completed frame 000899 - Found 5 detections
# Progress: 900/2146 frames processed in VID111
#
# Processing frame: 000900
# Completed frame 000900 - Found 6 detections
# Progress: 901/2146 frames processed in VID111
#
# Processing frame: 000901
# Completed frame 000901 - Found 4 detections
# Progress: 902/2146 frames processed in VID111
#
# Processing frame: 000902
# Completed frame 000902 - Found 3 detections
# Progress: 903/2146 frames processed in VID111
#
# Processing frame: 000903
# Completed frame 000903 - Found 3 detections
# Progress: 904/2146 frames processed in VID111
#
# Processing frame: 000904
# Completed frame 000904 - Found 3 detections
# Progress: 905/2146 frames processed in VID111
#
# Processing frame: 000905
# Completed frame 000905 - Found 3 detections
# Progress: 906/2146 frames processed in VID111
#
# Processing frame: 000906
# Completed frame 000906 - Found 4 detections
# Progress: 907/2146 frames processed in VID111
#
# Processing frame: 000907
# Completed frame 000907 - Found 2 detections
# Progress: 908/2146 frames processed in VID111
#
# Processing frame: 000908
# Completed frame 000908 - Found 4 detections
# Progress: 909/2146 frames processed in VID111
#
# Processing frame: 000909
# Completed frame 000909 - Found 5 detections
# Progress: 910/2146 frames processed in VID111
#
# Processing frame: 000910
# Completed frame 000910 - Found 3 detections
# Progress: 911/2146 frames processed in VID111
#
# Processing frame: 000911
# Completed frame 000911 - Found 3 detections
# Progress: 912/2146 frames processed in VID111
#
# Processing frame: 000912
# Completed frame 000912 - Found 5 detections
# Progress: 913/2146 frames processed in VID111
#
# Processing frame: 000913
# Completed frame 000913 - Found 4 detections
# Progress: 914/2146 frames processed in VID111
#
# Processing frame: 000914
# Completed frame 000914 - Found 3 detections
# Progress: 915/2146 frames processed in VID111
#
# Processing frame: 000915
# Completed frame 000915 - Found 4 detections
# Progress: 916/2146 frames processed in VID111
#
# Processing frame: 000916
# Completed frame 000916 - Found 3 detections
# Progress: 917/2146 frames processed in VID111
#
# Processing frame: 000917
# Completed frame 000917 - Found 3 detections
# Progress: 918/2146 frames processed in VID111
#
# Processing frame: 000918
# Completed frame 000918 - Found 3 detections
# Progress: 919/2146 frames processed in VID111
#
# Processing frame: 000919
# Completed frame 000919 - Found 4 detections
# Progress: 920/2146 frames processed in VID111
#
# Processing frame: 000920
# Completed frame 000920 - Found 4 detections
# Progress: 921/2146 frames processed in VID111
#
# Processing frame: 000921
# Completed frame 000921 - Found 3 detections
# Progress: 922/2146 frames processed in VID111
#
# Processing frame: 000922
# Completed frame 000922 - Found 3 detections
# Progress: 923/2146 frames processed in VID111
#
# Processing frame: 000923
# Completed frame 000923 - Found 5 detections
# Progress: 924/2146 frames processed in VID111
#
# Processing frame: 000924
# Completed frame 000924 - Found 3 detections
# Progress: 925/2146 frames processed in VID111
#
# Processing frame: 000925
# Completed frame 000925 - Found 4 detections
# Progress: 926/2146 frames processed in VID111
#
# Processing frame: 000926
# Completed frame 000926 - Found 3 detections
# Progress: 927/2146 frames processed in VID111
#
# Processing frame: 000927
# Completed frame 000927 - Found 3 detections
# Progress: 928/2146 frames processed in VID111
#
# Processing frame: 000928
# Completed frame 000928 - Found 3 detections
# Progress: 929/2146 frames processed in VID111
#
# Processing frame: 000929
# Completed frame 000929 - Found 4 detections
# Progress: 930/2146 frames processed in VID111
#
# Processing frame: 000930
# Completed frame 000930 - Found 4 detections
# Progress: 931/2146 frames processed in VID111
#
# Processing frame: 000931
# Completed frame 000931 - Found 6 detections
# Progress: 932/2146 frames processed in VID111
#
# Processing frame: 000932
# Completed frame 000932 - Found 3 detections
# Progress: 933/2146 frames processed in VID111
#
# Processing frame: 000933
# Completed frame 000933 - Found 2 detections
# Progress: 934/2146 frames processed in VID111
#
# Processing frame: 000934
# Completed frame 000934 - Found 4 detections
# Progress: 935/2146 frames processed in VID111
#
# Processing frame: 000935
# Completed frame 000935 - Found 2 detections
# Progress: 936/2146 frames processed in VID111
#
# Processing frame: 000936
# Completed frame 000936 - Found 3 detections
# Progress: 937/2146 frames processed in VID111
#
# Processing frame: 000937
# Completed frame 000937 - Found 4 detections
# Progress: 938/2146 frames processed in VID111
#
# Processing frame: 000938
# Completed frame 000938 - Found 4 detections
# Progress: 939/2146 frames processed in VID111
#
# Processing frame: 000939
# Completed frame 000939 - Found 6 detections
# Progress: 940/2146 frames processed in VID111
#
# Processing frame: 000940
# Completed frame 000940 - Found 2 detections
# Progress: 941/2146 frames processed in VID111
#
# Processing frame: 000941
# Completed frame 000941 - Found 3 detections
# Progress: 942/2146 frames processed in VID111
#
# Processing frame: 000942
# Completed frame 000942 - Found 4 detections
# Progress: 943/2146 frames processed in VID111
#
# Processing frame: 000943
# Completed frame 000943 - Found 2 detections
# Progress: 944/2146 frames processed in VID111
#
# Processing frame: 000944
# Completed frame 000944 - Found 4 detections
# Progress: 945/2146 frames processed in VID111
#
# Processing frame: 000945
# Completed frame 000945 - Found 3 detections
# Progress: 946/2146 frames processed in VID111
#
# Processing frame: 000946
# Completed frame 000946 - Found 5 detections
# Progress: 947/2146 frames processed in VID111
#
# Processing frame: 000947
# Completed frame 000947 - Found 7 detections
# Progress: 948/2146 frames processed in VID111
#
# Processing frame: 000948
# Completed frame 000948 - Found 2 detections
# Progress: 949/2146 frames processed in VID111
#
# Processing frame: 000949
# Completed frame 000949 - Found 2 detections
# Progress: 950/2146 frames processed in VID111
#
# Processing frame: 000950
# Completed frame 000950 - Found 3 detections
# Progress: 951/2146 frames processed in VID111
#
# Processing frame: 000951
# Completed frame 000951 - Found 4 detections
# Progress: 952/2146 frames processed in VID111
#
# Processing frame: 000952
# Completed frame 000952 - Found 2 detections
# Progress: 953/2146 frames processed in VID111
#
# Processing frame: 000953
# Completed frame 000953 - Found 3 detections
# Progress: 954/2146 frames processed in VID111
#
# Processing frame: 000954
# Completed frame 000954 - Found 2 detections
# Progress: 955/2146 frames processed in VID111
#
# Processing frame: 000955
# Completed frame 000955 - Found 2 detections
# Progress: 956/2146 frames processed in VID111
#
# Processing frame: 000956
# Completed frame 000956 - Found 2 detections
# Progress: 957/2146 frames processed in VID111
#
# Processing frame: 000957
# Completed frame 000957 - Found 2 detections
# Progress: 958/2146 frames processed in VID111
#
# Processing frame: 000958
# Completed frame 000958 - Found 2 detections
# Progress: 959/2146 frames processed in VID111
#
# Processing frame: 000959
# Completed frame 000959 - Found 2 detections
# Progress: 960/2146 frames processed in VID111
#
# Processing frame: 000960
# Completed frame 000960 - Found 2 detections
# Progress: 961/2146 frames processed in VID111
#
# Processing frame: 000961
# Completed frame 000961 - Found 6 detections
# Progress: 962/2146 frames processed in VID111
#
# Processing frame: 000962
# Completed frame 000962 - Found 2 detections
# Progress: 963/2146 frames processed in VID111
#
# Processing frame: 000963
# Completed frame 000963 - Found 1 detections
# Progress: 964/2146 frames processed in VID111
#
# Processing frame: 000964
# Completed frame 000964 - Found 1 detections
# Progress: 965/2146 frames processed in VID111
#
# Processing frame: 000965
# Completed frame 000965 - Found 2 detections
# Progress: 966/2146 frames processed in VID111
#
# Processing frame: 000966
# Completed frame 000966 - Found 2 detections
# Progress: 967/2146 frames processed in VID111
#
# Processing frame: 000967
# Completed frame 000967 - Found 3 detections
# Progress: 968/2146 frames processed in VID111
#
# Processing frame: 000968
# Completed frame 000968 - Found 2 detections
# Progress: 969/2146 frames processed in VID111
#
# Processing frame: 000969
# Completed frame 000969 - Found 2 detections
# Progress: 970/2146 frames processed in VID111
#
# Processing frame: 000970
# Completed frame 000970 - Found 2 detections
# Progress: 971/2146 frames processed in VID111
#
# Processing frame: 000971
# Completed frame 000971 - Found 4 detections
# Progress: 972/2146 frames processed in VID111
#
# Processing frame: 000972
# Completed frame 000972 - Found 4 detections
# Progress: 973/2146 frames processed in VID111
#
# Processing frame: 000973
# Completed frame 000973 - Found 6 detections
# Progress: 974/2146 frames processed in VID111
#
# Processing frame: 000974
# Completed frame 000974 - Found 3 detections
# Progress: 975/2146 frames processed in VID111
#
# Processing frame: 000975
# Completed frame 000975 - Found 2 detections
# Progress: 976/2146 frames processed in VID111
#
# Processing frame: 000976
# Completed frame 000976 - Found 2 detections
# Progress: 977/2146 frames processed in VID111
#
# Processing frame: 000977
# Completed frame 000977 - Found 2 detections
# Progress: 978/2146 frames processed in VID111
#
# Processing frame: 000978
# Completed frame 000978 - Found 2 detections
# Progress: 979/2146 frames processed in VID111
#
# Processing frame: 000979
# Completed frame 000979 - Found 2 detections
# Progress: 980/2146 frames processed in VID111
#
# Processing frame: 000980
# Completed frame 000980 - Found 2 detections
# Progress: 981/2146 frames processed in VID111
#
# Processing frame: 000981
# Completed frame 000981 - Found 3 detections
# Progress: 982/2146 frames processed in VID111
#
# Processing frame: 000982
# Completed frame 000982 - Found 5 detections
# Progress: 983/2146 frames processed in VID111
#
# Processing frame: 000983
# Completed frame 000983 - Found 2 detections
# Progress: 984/2146 frames processed in VID111
#
# Processing frame: 000984
# Completed frame 000984 - Found 3 detections
# Progress: 985/2146 frames processed in VID111
#
# Processing frame: 000985
# Completed frame 000985 - Found 5 detections
# Progress: 986/2146 frames processed in VID111
#
# Processing frame: 000986
# Completed frame 000986 - Found 3 detections
# Progress: 987/2146 frames processed in VID111
#
# Processing frame: 000987
# Completed frame 000987 - Found 2 detections
# Progress: 988/2146 frames processed in VID111
#
# Processing frame: 000988
# Completed frame 000988 - Found 3 detections
# Progress: 989/2146 frames processed in VID111
#
# Processing frame: 000989
# Completed frame 000989 - Found 3 detections
# Progress: 990/2146 frames processed in VID111
#
# Processing frame: 000990
# Completed frame 000990 - Found 4 detections
# Progress: 991/2146 frames processed in VID111
#
# Processing frame: 000991
# Completed frame 000991 - Found 4 detections
# Progress: 992/2146 frames processed in VID111
#
# Processing frame: 000992
# Completed frame 000992 - Found 3 detections
# Progress: 993/2146 frames processed in VID111
#
# Processing frame: 000993
# Completed frame 000993 - Found 2 detections
# Progress: 994/2146 frames processed in VID111
#
# Processing frame: 000994
# Completed frame 000994 - Found 5 detections
# Progress: 995/2146 frames processed in VID111
#
# Processing frame: 000995
# Completed frame 000995 - Found 3 detections
# Progress: 996/2146 frames processed in VID111
#
# Processing frame: 000996
# Completed frame 000996 - Found 3 detections
# Progress: 997/2146 frames processed in VID111
#
# Processing frame: 000997
# Completed frame 000997 - Found 6 detections
# Progress: 998/2146 frames processed in VID111
#
# Processing frame: 000998
# Completed frame 000998 - Found 3 detections
# Progress: 999/2146 frames processed in VID111
#
# Processing frame: 000999
# Completed frame 000999 - Found 4 detections
# Progress: 1000/2146 frames processed in VID111
#
# Processing frame: 001000
# Completed frame 001000 - Found 3 detections
# Progress: 1001/2146 frames processed in VID111
#
# Processing frame: 001001
# Completed frame 001001 - Found 5 detections
# Progress: 1002/2146 frames processed in VID111
#
# Processing frame: 001002
# Completed frame 001002 - Found 3 detections
# Progress: 1003/2146 frames processed in VID111
#
# Processing frame: 001003
# Completed frame 001003 - Found 4 detections
# Progress: 1004/2146 frames processed in VID111
#
# Processing frame: 001004
# Completed frame 001004 - Found 3 detections
# Progress: 1005/2146 frames processed in VID111
#
# Processing frame: 001005
# Completed frame 001005 - Found 3 detections
# Progress: 1006/2146 frames processed in VID111
#
# Processing frame: 001006
# Completed frame 001006 - Found 2 detections
# Progress: 1007/2146 frames processed in VID111
#
# Processing frame: 001007
# Completed frame 001007 - Found 2 detections
# Progress: 1008/2146 frames processed in VID111
#
# Processing frame: 001008
# Completed frame 001008 - Found 2 detections
# Progress: 1009/2146 frames processed in VID111
#
# Processing frame: 001009
# Completed frame 001009 - Found 2 detections
# Progress: 1010/2146 frames processed in VID111
#
# Processing frame: 001010
# Completed frame 001010 - Found 1 detections
# Progress: 1011/2146 frames processed in VID111
#
# Processing frame: 001011
# Completed frame 001011 - Found 2 detections
# Progress: 1012/2146 frames processed in VID111
#
# Processing frame: 001012
# Completed frame 001012 - Found 2 detections
# Progress: 1013/2146 frames processed in VID111
#
# Processing frame: 001013
# Completed frame 001013 - Found 1 detections
# Progress: 1014/2146 frames processed in VID111
#
# Processing frame: 001014
# Completed frame 001014 - Found 2 detections
# Progress: 1015/2146 frames processed in VID111
#
# Processing frame: 001015
# Completed frame 001015 - Found 2 detections
# Progress: 1016/2146 frames processed in VID111
#
# Processing frame: 001016
# Completed frame 001016 - Found 2 detections
# Progress: 1017/2146 frames processed in VID111
#
# Processing frame: 001017
# Completed frame 001017 - Found 1 detections
# Progress: 1018/2146 frames processed in VID111
#
# Processing frame: 001018
# Completed frame 001018 - Found 2 detections
# Progress: 1019/2146 frames processed in VID111
#
# Processing frame: 001019
# Completed frame 001019 - Found 4 detections
# Progress: 1020/2146 frames processed in VID111
#
# Processing frame: 001020
# Completed frame 001020 - Found 2 detections
# Progress: 1021/2146 frames processed in VID111
#
# Processing frame: 001021
# Completed frame 001021 - Found 2 detections
# Progress: 1022/2146 frames processed in VID111
#
# Processing frame: 001022
# Completed frame 001022 - Found 3 detections
# Progress: 1023/2146 frames processed in VID111
#
# Processing frame: 001023
# Completed frame 001023 - Found 2 detections
# Progress: 1024/2146 frames processed in VID111
#
# Processing frame: 001024
# Completed frame 001024 - Found 2 detections
# Progress: 1025/2146 frames processed in VID111
#
# Processing frame: 001025
# Completed frame 001025 - Found 2 detections
# Progress: 1026/2146 frames processed in VID111
#
# Processing frame: 001026
# Completed frame 001026 - Found 2 detections
# Progress: 1027/2146 frames processed in VID111
#
# Processing frame: 001027
# Completed frame 001027 - Found 2 detections
# Progress: 1028/2146 frames processed in VID111
#
# Processing frame: 001028
# Completed frame 001028 - Found 2 detections
# Progress: 1029/2146 frames processed in VID111
#
# Processing frame: 001029
# Completed frame 001029 - Found 2 detections
# Progress: 1030/2146 frames processed in VID111
#
# Processing frame: 001030
# Completed frame 001030 - Found 2 detections
# Progress: 1031/2146 frames processed in VID111
#
# Processing frame: 001031
# Completed frame 001031 - Found 5 detections
# Progress: 1032/2146 frames processed in VID111
#
# Processing frame: 001032
# Completed frame 001032 - Found 3 detections
# Progress: 1033/2146 frames processed in VID111
#
# Processing frame: 001033
# Completed frame 001033 - Found 3 detections
# Progress: 1034/2146 frames processed in VID111
#
# Processing frame: 001034
# Completed frame 001034 - Found 3 detections
# Progress: 1035/2146 frames processed in VID111
#
# Processing frame: 001035
# Completed frame 001035 - Found 5 detections
# Progress: 1036/2146 frames processed in VID111
#
# Processing frame: 001036
# Completed frame 001036 - Found 3 detections
# Progress: 1037/2146 frames processed in VID111
#
# Processing frame: 001037
# Completed frame 001037 - Found 6 detections
# Progress: 1038/2146 frames processed in VID111
#
# Processing frame: 001038
# Completed frame 001038 - Found 2 detections
# Progress: 1039/2146 frames processed in VID111
#
# Processing frame: 001039
# Completed frame 001039 - Found 2 detections
# Progress: 1040/2146 frames processed in VID111
#
# Processing frame: 001040
# Completed frame 001040 - Found 6 detections
# Progress: 1041/2146 frames processed in VID111
#
# Processing frame: 001041
# Completed frame 001041 - Found 4 detections
# Progress: 1042/2146 frames processed in VID111
#
# Processing frame: 001042
# Completed frame 001042 - Found 5 detections
# Progress: 1043/2146 frames processed in VID111
#
# Processing frame: 001043
# Completed frame 001043 - Found 2 detections
# Progress: 1044/2146 frames processed in VID111
#
# Processing frame: 001044
# Completed frame 001044 - Found 2 detections
# Progress: 1045/2146 frames processed in VID111
#
# Processing frame: 001045
# Completed frame 001045 - Found 4 detections
# Progress: 1046/2146 frames processed in VID111
#
# Processing frame: 001046
# Completed frame 001046 - Found 3 detections
# Progress: 1047/2146 frames processed in VID111
#
# Processing frame: 001047
# Completed frame 001047 - Found 5 detections
# Progress: 1048/2146 frames processed in VID111
#
# Processing frame: 001048
# Completed frame 001048 - Found 4 detections
# Progress: 1049/2146 frames processed in VID111
#
# Processing frame: 001049
# Completed frame 001049 - Found 5 detections
# Progress: 1050/2146 frames processed in VID111
#
# Processing frame: 001050
# Completed frame 001050 - Found 3 detections
# Progress: 1051/2146 frames processed in VID111
#
# Processing frame: 001051
# Completed frame 001051 - Found 4 detections
# Progress: 1052/2146 frames processed in VID111
#
# Processing frame: 001052
# Completed frame 001052 - Found 3 detections
# Progress: 1053/2146 frames processed in VID111
#
# Processing frame: 001053
# Completed frame 001053 - Found 3 detections
# Progress: 1054/2146 frames processed in VID111
#
# Processing frame: 001054
# Completed frame 001054 - Found 4 detections
# Progress: 1055/2146 frames processed in VID111
#
# Processing frame: 001055
# Completed frame 001055 - Found 3 detections
# Progress: 1056/2146 frames processed in VID111
#
# Processing frame: 001056
# Completed frame 001056 - Found 5 detections
# Progress: 1057/2146 frames processed in VID111
#
# Processing frame: 001057
# Completed frame 001057 - Found 4 detections
# Progress: 1058/2146 frames processed in VID111
#
# Processing frame: 001058
# Completed frame 001058 - Found 3 detections
# Progress: 1059/2146 frames processed in VID111
#
# Processing frame: 001059
# Completed frame 001059 - Found 4 detections
# Progress: 1060/2146 frames processed in VID111
#
# Processing frame: 001060
# Completed frame 001060 - Found 3 detections
# Progress: 1061/2146 frames processed in VID111
#
# Processing frame: 001061
# Completed frame 001061 - Found 4 detections
# Progress: 1062/2146 frames processed in VID111
#
# Processing frame: 001062
# Completed frame 001062 - Found 4 detections
# Progress: 1063/2146 frames processed in VID111
#
# Processing frame: 001063
# Completed frame 001063 - Found 4 detections
# Progress: 1064/2146 frames processed in VID111
#
# Processing frame: 001064
# Completed frame 001064 - Found 3 detections
# Progress: 1065/2146 frames processed in VID111
#
# Processing frame: 001065
# Completed frame 001065 - Found 3 detections
# Progress: 1066/2146 frames processed in VID111
#
# Processing frame: 001066
# Completed frame 001066 - Found 3 detections
# Progress: 1067/2146 frames processed in VID111
#
# Processing frame: 001067
# Completed frame 001067 - Found 4 detections
# Progress: 1068/2146 frames processed in VID111
#
# Processing frame: 001068
# Completed frame 001068 - Found 5 detections
# Progress: 1069/2146 frames processed in VID111
#
# Processing frame: 001069
# Completed frame 001069 - Found 2 detections
# Progress: 1070/2146 frames processed in VID111
#
# Processing frame: 001070
# Completed frame 001070 - Found 2 detections
# Progress: 1071/2146 frames processed in VID111
#
# Processing frame: 001071
# Completed frame 001071 - Found 3 detections
# Progress: 1072/2146 frames processed in VID111
#
# Processing frame: 001072
# Completed frame 001072 - Found 3 detections
# Progress: 1073/2146 frames processed in VID111
#
# Processing frame: 001073
# Completed frame 001073 - Found 5 detections
# Progress: 1074/2146 frames processed in VID111
#
# Processing frame: 001074
# Completed frame 001074 - Found 3 detections
# Progress: 1075/2146 frames processed in VID111
#
# Processing frame: 001075
# Completed frame 001075 - Found 5 detections
# Progress: 1076/2146 frames processed in VID111
#
# Processing frame: 001076
# Completed frame 001076 - Found 4 detections
# Progress: 1077/2146 frames processed in VID111
#
# Processing frame: 001077
# Completed frame 001077 - Found 3 detections
# Progress: 1078/2146 frames processed in VID111
#
# Processing frame: 001078
# Completed frame 001078 - Found 5 detections
# Progress: 1079/2146 frames processed in VID111
#
# Processing frame: 001079
# Completed frame 001079 - Found 3 detections
# Progress: 1080/2146 frames processed in VID111
#
# Processing frame: 001080
# Completed frame 001080 - Found 2 detections
# Progress: 1081/2146 frames processed in VID111
#
# Processing frame: 001081
# Completed frame 001081 - Found 5 detections
# Progress: 1082/2146 frames processed in VID111
#
# Processing frame: 001082
# Completed frame 001082 - Found 3 detections
# Progress: 1083/2146 frames processed in VID111
#
# Processing frame: 001083
# Completed frame 001083 - Found 5 detections
# Progress: 1084/2146 frames processed in VID111
#
# Processing frame: 001084
# Completed frame 001084 - Found 3 detections
# Progress: 1085/2146 frames processed in VID111
#
# Processing frame: 001085
# Completed frame 001085 - Found 2 detections
# Progress: 1086/2146 frames processed in VID111
#
# Processing frame: 001086
# Completed frame 001086 - Found 3 detections
# Progress: 1087/2146 frames processed in VID111
#
# Processing frame: 001087
# Completed frame 001087 - Found 4 detections
# Progress: 1088/2146 frames processed in VID111
#
# Processing frame: 001088
# Completed frame 001088 - Found 2 detections
# Progress: 1089/2146 frames processed in VID111
#
# Processing frame: 001089
# Completed frame 001089 - Found 4 detections
# Progress: 1090/2146 frames processed in VID111
#
# Processing frame: 001090
# Completed frame 001090 - Found 5 detections
# Progress: 1091/2146 frames processed in VID111
#
# Processing frame: 001091
# Completed frame 001091 - Found 5 detections
# Progress: 1092/2146 frames processed in VID111
#
# Processing frame: 001092
# Completed frame 001092 - Found 4 detections
# Progress: 1093/2146 frames processed in VID111
#
# Processing frame: 001093
# Completed frame 001093 - Found 4 detections
# Progress: 1094/2146 frames processed in VID111
#
# Processing frame: 001094
# Completed frame 001094 - Found 4 detections
# Progress: 1095/2146 frames processed in VID111
#
# Processing frame: 001095
# Completed frame 001095 - Found 3 detections
# Progress: 1096/2146 frames processed in VID111
#
# Processing frame: 001096
# Completed frame 001096 - Found 3 detections
# Progress: 1097/2146 frames processed in VID111
#
# Processing frame: 001097
# Completed frame 001097 - Found 4 detections
# Progress: 1098/2146 frames processed in VID111
#
# Processing frame: 001098
# Completed frame 001098 - Found 6 detections
# Progress: 1099/2146 frames processed in VID111
#
# Processing frame: 001099
# Completed frame 001099 - Found 4 detections
# Progress: 1100/2146 frames processed in VID111
#
# Processing frame: 001100
# Completed frame 001100 - Found 5 detections
# Progress: 1101/2146 frames processed in VID111
#
# Processing frame: 001101
# Completed frame 001101 - Found 2 detections
# Progress: 1102/2146 frames processed in VID111
#
# Processing frame: 001102
# Completed frame 001102 - Found 4 detections
# Progress: 1103/2146 frames processed in VID111
#
# Processing frame: 001103
# Completed frame 001103 - Found 5 detections
# Progress: 1104/2146 frames processed in VID111
#
# Processing frame: 001104
# Completed frame 001104 - Found 4 detections
# Progress: 1105/2146 frames processed in VID111
#
# Processing frame: 001105
# Completed frame 001105 - Found 3 detections
# Progress: 1106/2146 frames processed in VID111
#
# Processing frame: 001106
# Completed frame 001106 - Found 3 detections
# Progress: 1107/2146 frames processed in VID111
#
# Processing frame: 001107
# Completed frame 001107 - Found 3 detections
# Progress: 1108/2146 frames processed in VID111
#
# Processing frame: 001108
# Completed frame 001108 - Found 3 detections
# Progress: 1109/2146 frames processed in VID111
#
# Processing frame: 001109
# Completed frame 001109 - Found 3 detections
# Progress: 1110/2146 frames processed in VID111
#
# Processing frame: 001110
# Completed frame 001110 - Found 4 detections
# Progress: 1111/2146 frames processed in VID111
#
# Processing frame: 001111
# Completed frame 001111 - Found 2 detections
# Progress: 1112/2146 frames processed in VID111
#
# Processing frame: 001112
# Completed frame 001112 - Found 4 detections
# Progress: 1113/2146 frames processed in VID111
#
# Processing frame: 001113
# Completed frame 001113 - Found 5 detections
# Progress: 1114/2146 frames processed in VID111
#
# Processing frame: 001114
# Completed frame 001114 - Found 4 detections
# Progress: 1115/2146 frames processed in VID111
#
# Processing frame: 001115
# Completed frame 001115 - Found 5 detections
# Progress: 1116/2146 frames processed in VID111
#
# Processing frame: 001116
# Completed frame 001116 - Found 5 detections
# Progress: 1117/2146 frames processed in VID111
#
# Processing frame: 001117
# Completed frame 001117 - Found 3 detections
# Progress: 1118/2146 frames processed in VID111
#
# Processing frame: 001118
# Completed frame 001118 - Found 3 detections
# Progress: 1119/2146 frames processed in VID111
#
# Processing frame: 001119
# Completed frame 001119 - Found 5 detections
# Progress: 1120/2146 frames processed in VID111
#
# Processing frame: 001120
# Completed frame 001120 - Found 3 detections
# Progress: 1121/2146 frames processed in VID111
#
# Processing frame: 001121
# Completed frame 001121 - Found 4 detections
# Progress: 1122/2146 frames processed in VID111
#
# Processing frame: 001122
# Completed frame 001122 - Found 3 detections
# Progress: 1123/2146 frames processed in VID111
#
# Processing frame: 001123
# Completed frame 001123 - Found 2 detections
# Progress: 1124/2146 frames processed in VID111
#
# Processing frame: 001124
# Completed frame 001124 - Found 2 detections
# Progress: 1125/2146 frames processed in VID111
#
# Processing frame: 001125
# Completed frame 001125 - Found 5 detections
# Progress: 1126/2146 frames processed in VID111
#
# Processing frame: 001126
# Completed frame 001126 - Found 4 detections
# Progress: 1127/2146 frames processed in VID111
#
# Processing frame: 001127
# Completed frame 001127 - Found 3 detections
# Progress: 1128/2146 frames processed in VID111
#
# Processing frame: 001128
# Completed frame 001128 - Found 3 detections
# Progress: 1129/2146 frames processed in VID111
#
# Processing frame: 001129
# Completed frame 001129 - Found 2 detections
# Progress: 1130/2146 frames processed in VID111
#
# Processing frame: 001130
# Completed frame 001130 - Found 2 detections
# Progress: 1131/2146 frames processed in VID111
#
# Processing frame: 001131
# Completed frame 001131 - Found 3 detections
# Progress: 1132/2146 frames processed in VID111
#
# Processing frame: 001132
# Completed frame 001132 - Found 3 detections
# Progress: 1133/2146 frames processed in VID111
#
# Processing frame: 001133
# Completed frame 001133 - Found 5 detections
# Progress: 1134/2146 frames processed in VID111
#
# Processing frame: 001134
# Completed frame 001134 - Found 4 detections
# Progress: 1135/2146 frames processed in VID111
#
# Processing frame: 001135
# Completed frame 001135 - Found 5 detections
# Progress: 1136/2146 frames processed in VID111
#
# Processing frame: 001136
# Completed frame 001136 - Found 4 detections
# Progress: 1137/2146 frames processed in VID111
#
# Processing frame: 001137
# Completed frame 001137 - Found 3 detections
# Progress: 1138/2146 frames processed in VID111
#
# Processing frame: 001138
# Completed frame 001138 - Found 2 detections
# Progress: 1139/2146 frames processed in VID111
#
# Processing frame: 001139
# Completed frame 001139 - Found 3 detections
# Progress: 1140/2146 frames processed in VID111
#
# Processing frame: 001140
# Completed frame 001140 - Found 3 detections
# Progress: 1141/2146 frames processed in VID111
#
# Processing frame: 001141
# Completed frame 001141 - Found 1 detections
# Progress: 1142/2146 frames processed in VID111
#
# Processing frame: 001142
# Completed frame 001142 - Found 2 detections
# Progress: 1143/2146 frames processed in VID111
#
# Processing frame: 001143
# Completed frame 001143 - Found 1 detections
# Progress: 1144/2146 frames processed in VID111
#
# Processing frame: 001144
# Completed frame 001144 - Found 3 detections
# Progress: 1145/2146 frames processed in VID111
#
# Processing frame: 001145
# Completed frame 001145 - Found 3 detections
# Progress: 1146/2146 frames processed in VID111
#
# Processing frame: 001146
# Completed frame 001146 - Found 2 detections
# Progress: 1147/2146 frames processed in VID111
#
# Processing frame: 001147
# Completed frame 001147 - Found 4 detections
# Progress: 1148/2146 frames processed in VID111
#
# Processing frame: 001148
# Completed frame 001148 - Found 3 detections
# Progress: 1149/2146 frames processed in VID111
#
# Processing frame: 001149
# Completed frame 001149 - Found 3 detections
# Progress: 1150/2146 frames processed in VID111
#
# Processing frame: 001150
# Completed frame 001150 - Found 3 detections
# Progress: 1151/2146 frames processed in VID111
#
# Processing frame: 001151
# Completed frame 001151 - Found 2 detections
# Progress: 1152/2146 frames processed in VID111
#
# Processing frame: 001152
# Completed frame 001152 - Found 2 detections
# Progress: 1153/2146 frames processed in VID111
#
# Processing frame: 001153
# Completed frame 001153 - Found 2 detections
# Progress: 1154/2146 frames processed in VID111
#
# Processing frame: 001154
# Completed frame 001154 - Found 3 detections
# Progress: 1155/2146 frames processed in VID111
#
# Processing frame: 001155
# Completed frame 001155 - Found 3 detections
# Progress: 1156/2146 frames processed in VID111
#
# Processing frame: 001156
# Completed frame 001156 - Found 3 detections
# Progress: 1157/2146 frames processed in VID111
#
# Processing frame: 001157
# Completed frame 001157 - Found 2 detections
# Progress: 1158/2146 frames processed in VID111
#
# Processing frame: 001158
# Completed frame 001158 - Found 3 detections
# Progress: 1159/2146 frames processed in VID111
#
# Processing frame: 001159
# Completed frame 001159 - Found 3 detections
# Progress: 1160/2146 frames processed in VID111
#
# Processing frame: 001160
# Completed frame 001160 - Found 3 detections
# Progress: 1161/2146 frames processed in VID111
#
# Processing frame: 001161
# Completed frame 001161 - Found 2 detections
# Progress: 1162/2146 frames processed in VID111
#
# Processing frame: 001162
# Completed frame 001162 - Found 2 detections
# Progress: 1163/2146 frames processed in VID111
#
# Processing frame: 001163
# Completed frame 001163 - Found 3 detections
# Progress: 1164/2146 frames processed in VID111
#
# Processing frame: 001164
# Completed frame 001164 - Found 2 detections
# Progress: 1165/2146 frames processed in VID111
#
# Processing frame: 001165
# Completed frame 001165 - Found 3 detections
# Progress: 1166/2146 frames processed in VID111
#
# Processing frame: 001166
# Completed frame 001166 - Found 3 detections
# Progress: 1167/2146 frames processed in VID111
#
# Processing frame: 001167
# Completed frame 001167 - Found 3 detections
# Progress: 1168/2146 frames processed in VID111
#
# Processing frame: 001168
# Completed frame 001168 - Found 3 detections
# Progress: 1169/2146 frames processed in VID111
#
# Processing frame: 001169
# Completed frame 001169 - Found 3 detections
# Progress: 1170/2146 frames processed in VID111
#
# Processing frame: 001170
# Completed frame 001170 - Found 4 detections
# Progress: 1171/2146 frames processed in VID111
#
# Processing frame: 001171
# Completed frame 001171 - Found 6 detections
# Progress: 1172/2146 frames processed in VID111
#
# Processing frame: 001172
# Completed frame 001172 - Found 4 detections
# Progress: 1173/2146 frames processed in VID111
#
# Processing frame: 001173
# Completed frame 001173 - Found 4 detections
# Progress: 1174/2146 frames processed in VID111
#
# Processing frame: 001174
# Completed frame 001174 - Found 3 detections
# Progress: 1175/2146 frames processed in VID111
#
# Processing frame: 001175
# Completed frame 001175 - Found 3 detections
# Progress: 1176/2146 frames processed in VID111
#
# Processing frame: 001176
# Completed frame 001176 - Found 3 detections
# Progress: 1177/2146 frames processed in VID111
#
# Processing frame: 001177
# Completed frame 001177 - Found 2 detections
# Progress: 1178/2146 frames processed in VID111
#
# Processing frame: 001178
# Completed frame 001178 - Found 5 detections
# Progress: 1179/2146 frames processed in VID111
#
# Processing frame: 001179
# Completed frame 001179 - Found 2 detections
# Progress: 1180/2146 frames processed in VID111
#
# Processing frame: 001180
# Completed frame 001180 - Found 3 detections
# Progress: 1181/2146 frames processed in VID111
#
# Processing frame: 001181
# Completed frame 001181 - Found 3 detections
# Progress: 1182/2146 frames processed in VID111
#
# Processing frame: 001182
# Completed frame 001182 - Found 3 detections
# Progress: 1183/2146 frames processed in VID111
#
# Processing frame: 001183
# Completed frame 001183 - Found 3 detections
# Progress: 1184/2146 frames processed in VID111
#
# Processing frame: 001184
# Completed frame 001184 - Found 3 detections
# Progress: 1185/2146 frames processed in VID111
#
# Processing frame: 001185
# Completed frame 001185 - Found 4 detections
# Progress: 1186/2146 frames processed in VID111
#
# Processing frame: 001186
# Completed frame 001186 - Found 3 detections
# Progress: 1187/2146 frames processed in VID111
#
# Processing frame: 001187
# Completed frame 001187 - Found 5 detections
# Progress: 1188/2146 frames processed in VID111
#
# Processing frame: 001188
# Completed frame 001188 - Found 3 detections
# Progress: 1189/2146 frames processed in VID111
#
# Processing frame: 001189
# Completed frame 001189 - Found 3 detections
# Progress: 1190/2146 frames processed in VID111
#
# Processing frame: 001190
# Completed frame 001190 - Found 2 detections
# Progress: 1191/2146 frames processed in VID111
#
# Processing frame: 001191
# Completed frame 001191 - Found 3 detections
# Progress: 1192/2146 frames processed in VID111
#
# Processing frame: 001192
# Completed frame 001192 - Found 3 detections
# Progress: 1193/2146 frames processed in VID111
#
# Processing frame: 001193
# Completed frame 001193 - Found 2 detections
# Progress: 1194/2146 frames processed in VID111
#
# Processing frame: 001194
# Completed frame 001194 - Found 2 detections
# Progress: 1195/2146 frames processed in VID111
#
# Processing frame: 001195
# Completed frame 001195 - Found 3 detections
# Progress: 1196/2146 frames processed in VID111
#
# Processing frame: 001196
# Completed frame 001196 - Found 1 detections
# Progress: 1197/2146 frames processed in VID111
#
# Processing frame: 001197
# Completed frame 001197 - Found 2 detections
# Progress: 1198/2146 frames processed in VID111
#
# Processing frame: 001198
# Completed frame 001198 - Found 2 detections
# Progress: 1199/2146 frames processed in VID111
#
# Processing frame: 001199
# Completed frame 001199 - Found 2 detections
# Progress: 1200/2146 frames processed in VID111
#
# Processing frame: 001200
# Completed frame 001200 - Found 2 detections
# Progress: 1201/2146 frames processed in VID111
#
# Processing frame: 001201
# Completed frame 001201 - Found 2 detections
# Progress: 1202/2146 frames processed in VID111
#
# Processing frame: 001202
# Completed frame 001202 - Found 3 detections
# Progress: 1203/2146 frames processed in VID111
#
# Processing frame: 001203
# Completed frame 001203 - Found 2 detections
# Progress: 1204/2146 frames processed in VID111
#
# Processing frame: 001204
# Completed frame 001204 - Found 3 detections
# Progress: 1205/2146 frames processed in VID111
#
# Processing frame: 001205
# Completed frame 001205 - Found 3 detections
# Progress: 1206/2146 frames processed in VID111
#
# Processing frame: 001206
# Completed frame 001206 - Found 3 detections
# Progress: 1207/2146 frames processed in VID111
#
# Processing frame: 001207
# Completed frame 001207 - Found 2 detections
# Progress: 1208/2146 frames processed in VID111
#
# Processing frame: 001208
# Completed frame 001208 - Found 2 detections
# Progress: 1209/2146 frames processed in VID111
#
# Processing frame: 001209
# Completed frame 001209 - Found 1 detections
# Progress: 1210/2146 frames processed in VID111
#
# Processing frame: 001210
# Completed frame 001210 - Found 2 detections
# Progress: 1211/2146 frames processed in VID111
#
# Processing frame: 001211
# Completed frame 001211 - Found 2 detections
# Progress: 1212/2146 frames processed in VID111
#
# Processing frame: 001212
# Completed frame 001212 - Found 1 detections
# Progress: 1213/2146 frames processed in VID111
#
# Processing frame: 001213
# Completed frame 001213 - Found 3 detections
# Progress: 1214/2146 frames processed in VID111
#
# Processing frame: 001214
# Completed frame 001214 - Found 3 detections
# Progress: 1215/2146 frames processed in VID111
#
# Processing frame: 001215
# Completed frame 001215 - Found 3 detections
# Progress: 1216/2146 frames processed in VID111
#
# Processing frame: 001216
# Completed frame 001216 - Found 4 detections
# Progress: 1217/2146 frames processed in VID111
#
# Processing frame: 001217
# Completed frame 001217 - Found 2 detections
# Progress: 1218/2146 frames processed in VID111
#
# Processing frame: 001218
# Completed frame 001218 - Found 2 detections
# Progress: 1219/2146 frames processed in VID111
#
# Processing frame: 001219
# Completed frame 001219 - Found 2 detections
# Progress: 1220/2146 frames processed in VID111
#
# Processing frame: 001220
# Completed frame 001220 - Found 2 detections
# Progress: 1221/2146 frames processed in VID111
#
# Processing frame: 001221
# Completed frame 001221 - Found 3 detections
# Progress: 1222/2146 frames processed in VID111
#
# Processing frame: 001222
# Completed frame 001222 - Found 2 detections
# Progress: 1223/2146 frames processed in VID111
#
# Processing frame: 001223
# Completed frame 001223 - Found 3 detections
# Progress: 1224/2146 frames processed in VID111
#
# Processing frame: 001224
# Completed frame 001224 - Found 2 detections
# Progress: 1225/2146 frames processed in VID111
#
# Processing frame: 001225
# Completed frame 001225 - Found 2 detections
# Progress: 1226/2146 frames processed in VID111
#
# Processing frame: 001226
# Completed frame 001226 - Found 2 detections
# Progress: 1227/2146 frames processed in VID111
#
# Processing frame: 001227
# Completed frame 001227 - Found 2 detections
# Progress: 1228/2146 frames processed in VID111
#
# Processing frame: 001228
# Completed frame 001228 - Found 2 detections
# Progress: 1229/2146 frames processed in VID111
#
# Processing frame: 001229
# Completed frame 001229 - Found 3 detections
# Progress: 1230/2146 frames processed in VID111
#
# Processing frame: 001230
# Completed frame 001230 - Found 2 detections
# Progress: 1231/2146 frames processed in VID111
#
# Processing frame: 001231
# Completed frame 001231 - Found 2 detections
# Progress: 1232/2146 frames processed in VID111
#
# Processing frame: 001232
# Completed frame 001232 - Found 2 detections
# Progress: 1233/2146 frames processed in VID111
#
# Processing frame: 001233
# Completed frame 001233 - Found 3 detections
# Progress: 1234/2146 frames processed in VID111
#
# Processing frame: 001234
# Completed frame 001234 - Found 2 detections
# Progress: 1235/2146 frames processed in VID111
#
# Processing frame: 001235
# Completed frame 001235 - Found 1 detections
# Progress: 1236/2146 frames processed in VID111
#
# Processing frame: 001236
# Completed frame 001236 - Found 3 detections
# Progress: 1237/2146 frames processed in VID111
#
# Processing frame: 001237
# Completed frame 001237 - Found 3 detections
# Progress: 1238/2146 frames processed in VID111
#
# Processing frame: 001238
# Completed frame 001238 - Found 3 detections
# Progress: 1239/2146 frames processed in VID111
#
# Processing frame: 001239
# Completed frame 001239 - Found 1 detections
# Progress: 1240/2146 frames processed in VID111
#
# Processing frame: 001240
# Completed frame 001240 - Found 2 detections
# Progress: 1241/2146 frames processed in VID111
#
# Processing frame: 001241
# Completed frame 001241 - Found 2 detections
# Progress: 1242/2146 frames processed in VID111
#
# Processing frame: 001242
# Completed frame 001242 - Found 2 detections
# Progress: 1243/2146 frames processed in VID111
#
# Processing frame: 001243
# Completed frame 001243 - Found 3 detections
# Progress: 1244/2146 frames processed in VID111
#
# Processing frame: 001244
# Completed frame 001244 - Found 2 detections
# Progress: 1245/2146 frames processed in VID111
#
# Processing frame: 001245
# Completed frame 001245 - Found 2 detections
# Progress: 1246/2146 frames processed in VID111
#
# Processing frame: 001246
# Completed frame 001246 - Found 2 detections
# Progress: 1247/2146 frames processed in VID111
#
# Processing frame: 001247
# Completed frame 001247 - Found 3 detections
# Progress: 1248/2146 frames processed in VID111
#
# Processing frame: 001248
# Completed frame 001248 - Found 4 detections
# Progress: 1249/2146 frames processed in VID111
#
# Processing frame: 001249
# Completed frame 001249 - Found 3 detections
# Progress: 1250/2146 frames processed in VID111
#
# Processing frame: 001250
# Completed frame 001250 - Found 1 detections
# Progress: 1251/2146 frames processed in VID111
#
# Processing frame: 001251
# Completed frame 001251 - Found 3 detections
# Progress: 1252/2146 frames processed in VID111
#
# Processing frame: 001252
# Completed frame 001252 - Found 4 detections
# Progress: 1253/2146 frames processed in VID111
#
# Processing frame: 001253
# Completed frame 001253 - Found 3 detections
# Progress: 1254/2146 frames processed in VID111
#
# Processing frame: 001254
# Completed frame 001254 - Found 1 detections
# Progress: 1255/2146 frames processed in VID111
#
# Processing frame: 001255
# Completed frame 001255 - Found 1 detections
# Progress: 1256/2146 frames processed in VID111
#
# Processing frame: 001256
# Completed frame 001256 - Found 2 detections
# Progress: 1257/2146 frames processed in VID111
#
# Processing frame: 001257
# Completed frame 001257 - Found 3 detections
# Progress: 1258/2146 frames processed in VID111
#
# Processing frame: 001258
# Completed frame 001258 - Found 2 detections
# Progress: 1259/2146 frames processed in VID111
#
# Processing frame: 001259
# Completed frame 001259 - Found 2 detections
# Progress: 1260/2146 frames processed in VID111
#
# Processing frame: 001260
# Completed frame 001260 - Found 3 detections
# Progress: 1261/2146 frames processed in VID111
#
# Processing frame: 001261
# Completed frame 001261 - Found 1 detections
# Progress: 1262/2146 frames processed in VID111
#
# Processing frame: 001262
# Completed frame 001262 - Found 3 detections
# Progress: 1263/2146 frames processed in VID111
#
# Processing frame: 001263
# Completed frame 001263 - Found 2 detections
# Progress: 1264/2146 frames processed in VID111
#
# Processing frame: 001264
# Completed frame 001264 - Found 3 detections
# Progress: 1265/2146 frames processed in VID111
#
# Processing frame: 001265
# Completed frame 001265 - Found 4 detections
# Progress: 1266/2146 frames processed in VID111
#
# Processing frame: 001266
# Completed frame 001266 - Found 2 detections
# Progress: 1267/2146 frames processed in VID111
#
# Processing frame: 001267
# Completed frame 001267 - Found 2 detections
# Progress: 1268/2146 frames processed in VID111
#
# Processing frame: 001268
# Completed frame 001268 - Found 2 detections
# Progress: 1269/2146 frames processed in VID111
#
# Processing frame: 001269
# Completed frame 001269 - Found 2 detections
# Progress: 1270/2146 frames processed in VID111
#
# Processing frame: 001270
# Completed frame 001270 - Found 4 detections
# Progress: 1271/2146 frames processed in VID111
#
# Processing frame: 001271
# Completed frame 001271 - Found 2 detections
# Progress: 1272/2146 frames processed in VID111
#
# Processing frame: 001272
# Completed frame 001272 - Found 3 detections
# Progress: 1273/2146 frames processed in VID111
#
# Processing frame: 001273
# Completed frame 001273 - Found 1 detections
# Progress: 1274/2146 frames processed in VID111
#
# Processing frame: 001274
# Completed frame 001274 - Found 3 detections
# Progress: 1275/2146 frames processed in VID111
#
# Processing frame: 001275
# Completed frame 001275 - Found 2 detections
# Progress: 1276/2146 frames processed in VID111
#
# Processing frame: 001276
# Completed frame 001276 - Found 3 detections
# Progress: 1277/2146 frames processed in VID111
#
# Processing frame: 001277
# Completed frame 001277 - Found 3 detections
# Progress: 1278/2146 frames processed in VID111
#
# Processing frame: 001278
# Completed frame 001278 - Found 2 detections
# Progress: 1279/2146 frames processed in VID111
#
# Processing frame: 001279
# Completed frame 001279 - Found 3 detections
# Progress: 1280/2146 frames processed in VID111
#
# Processing frame: 001280
# Completed frame 001280 - Found 4 detections
# Progress: 1281/2146 frames processed in VID111
#
# Processing frame: 001281
# Completed frame 001281 - Found 2 detections
# Progress: 1282/2146 frames processed in VID111
#
# Processing frame: 001282
# Completed frame 001282 - Found 2 detections
# Progress: 1283/2146 frames processed in VID111
#
# Processing frame: 001283
# Completed frame 001283 - Found 3 detections
# Progress: 1284/2146 frames processed in VID111
#
# Processing frame: 001284
# Completed frame 001284 - Found 1 detections
# Progress: 1285/2146 frames processed in VID111
#
# Processing frame: 001285
# Completed frame 001285 - Found 2 detections
# Progress: 1286/2146 frames processed in VID111
#
# Processing frame: 001286
# Completed frame 001286 - Found 1 detections
# Progress: 1287/2146 frames processed in VID111
#
# Processing frame: 001287
# Completed frame 001287 - Found 1 detections
# Progress: 1288/2146 frames processed in VID111
#
# Processing frame: 001288
# Completed frame 001288 - Found 1 detections
# Progress: 1289/2146 frames processed in VID111
#
# Processing frame: 001289
# Completed frame 001289 - Found 3 detections
# ...
# Completed frame 002010 - Found 3 detections
# Progress: 2011/2146 frames processed in VID111
#
# Processing frame: 002011
# Completed frame 002011 - Found 3 detections
# Progress: 2012/2146 frames processed in VID111
#
# Processing frame: 002012
# Completed frame 002012 - Found 4 detections
# Progress: 2013/2146 frames processed in VID111
#
# Processing frame: 002013
# Completed frame 002013 - Found 2 detections
# Progress: 2014/2146 frames processed in VID111
#
# Processing frame: 002014
# Completed frame 002014 - Found 3 detections
# Progress: 2015/2146 frames processed in VID111
#
# Processing frame: 002015
# Completed frame 002015 - Found 4 detections
# Progress: 2016/2146 frames processed in VID111
#
# Processing frame: 002016
# Completed frame 002016 - Found 3 detections
# Progress: 2017/2146 frames processed in VID111
#
# Processing frame: 002017
# Completed frame 002017 - Found 4 detections
# Progress: 2018/2146 frames processed in VID111
#
# Processing frame: 002018
# Completed frame 002018 - Found 4 detections
# Progress: 2019/2146 frames processed in VID111
#
# Processing frame: 002019
# Completed frame 002019 - Found 3 detections
# Progress: 2020/2146 frames processed in VID111
#
# Processing frame: 002020
# Completed frame 002020 - Found 5 detections
# Progress: 2021/2146 frames processed in VID111
#
# Processing frame: 002021
# Completed frame 002021 - Found 4 detections
# Progress: 2022/2146 frames processed in VID111
#
# Processing frame: 002022
# Completed frame 002022 - Found 3 detections
# Progress: 2023/2146 frames processed in VID111
#
# Processing frame: 002023
# Completed frame 002023 - Found 5 detections
# Progress: 2024/2146 frames processed in VID111
#
# Processing frame: 002024
# Completed frame 002024 - Found 4 detections
# Progress: 2025/2146 frames processed in VID111
#
# Processing frame: 002025
# Completed frame 002025 - Found 3 detections
# Progress: 2026/2146 frames processed in VID111
#
# Processing frame: 002026
# Completed frame 002026 - Found 2 detections
# Progress: 2027/2146 frames processed in VID111
#
# Processing frame: 002027
# Completed frame 002027 - Found 3 detections
# Progress: 2028/2146 frames processed in VID111
#
# Processing frame: 002028
# Completed frame 002028 - Found 4 detections
# Progress: 2029/2146 frames processed in VID111
#
# Processing frame: 002029
# Completed frame 002029 - Found 1 detections
# Progress: 2030/2146 frames processed in VID111
#
# Processing frame: 002030
# Completed frame 002030 - Found 1 detections
# Progress: 2031/2146 frames processed in VID111
#
# Processing frame: 002031
# Completed frame 002031 - Found 1 detections
# Progress: 2032/2146 frames processed in VID111
#
# Processing frame: 002032
# Completed frame 002032 - Found 1 detections
# Progress: 2033/2146 frames processed in VID111
#
# Processing frame: 002033
# Completed frame 002033 - Found 1 detections
# Progress: 2034/2146 frames processed in VID111
#
# Processing frame: 002034
# Completed frame 002034 - Found 1 detections
# Progress: 2035/2146 frames processed in VID111
#
# Processing frame: 002035
# Completed frame 002035 - Found 1 detections
# Progress: 2036/2146 frames processed in VID111
#
# Processing frame: 002036
# Completed frame 002036 - Found 1 detections
# Progress: 2037/2146 frames processed in VID111
#
# Processing frame: 002037
# Completed frame 002037 - Found 1 detections
# Progress: 2038/2146 frames processed in VID111
#
# Processing frame: 002038
# Completed frame 002038 - Found 1 detections
# Progress: 2039/2146 frames processed in VID111
#
# Processing frame: 002039
# Completed frame 002039 - Found 1 detections
# Progress: 2040/2146 frames processed in VID111
#
# Processing frame: 002040
# Completed frame 002040 - Found 1 detections
# Progress: 2041/2146 frames processed in VID111
#
# Processing frame: 002041
# Completed frame 002041 - Found 1 detections
# Progress: 2042/2146 frames processed in VID111
#
# Processing frame: 002042
# Completed frame 002042 - Found 1 detections
# Progress: 2043/2146 frames processed in VID111
#
# Processing frame: 002043
# Completed frame 002043 - Found 1 detections
# Progress: 2044/2146 frames processed in VID111
#
# Processing frame: 002044
# Completed frame 002044 - Found 1 detections
# Progress: 2045/2146 frames processed in VID111
#
# Processing frame: 002045
# Completed frame 002045 - Found 1 detections
# Progress: 2046/2146 frames processed in VID111
#
# Processing frame: 002046
# Completed frame 002046 - Found 1 detections
# Progress: 2047/2146 frames processed in VID111
#
# Processing frame: 002047
# Completed frame 002047 - Found 1 detections
# Progress: 2048/2146 frames processed in VID111
#
# Processing frame: 002048
# Completed frame 002048 - Found 1 detections
# Progress: 2049/2146 frames processed in VID111
#
# Processing frame: 002049
# Completed frame 002049 - Found 1 detections
# Progress: 2050/2146 frames processed in VID111
#
# Processing frame: 002050
# Completed frame 002050 - Found 1 detections
# Progress: 2051/2146 frames processed in VID111
#
# Processing frame: 002051
# Completed frame 002051 - Found 1 detections
# Progress: 2052/2146 frames processed in VID111
#
# Processing frame: 002052
# Completed frame 002052 - Found 1 detections
# Progress: 2053/2146 frames processed in VID111
#
# Processing frame: 002053
# Completed frame 002053 - Found 1 detections
# Progress: 2054/2146 frames processed in VID111
#
# Processing frame: 002054
# Completed frame 002054 - Found 1 detections
# Progress: 2055/2146 frames processed in VID111
#
# Processing frame: 002055
# Completed frame 002055 - Found 1 detections
# Progress: 2056/2146 frames processed in VID111
#
# Processing frame: 002056
# Completed frame 002056 - Found 1 detections
# Progress: 2057/2146 frames processed in VID111
#
# Processing frame: 002057
# Completed frame 002057 - Found 1 detections
# Progress: 2058/2146 frames processed in VID111
#
# Processing frame: 002058
# Completed frame 002058 - Found 1 detections
# Progress: 2059/2146 frames processed in VID111
#
# Processing frame: 002059
# Completed frame 002059 - Found 1 detections
# Progress: 2060/2146 frames processed in VID111
#
# Processing frame: 002060
# Completed frame 002060 - Found 1 detections
# Progress: 2061/2146 frames processed in VID111
#
# Processing frame: 002061
# Completed frame 002061 - Found 1 detections
# Progress: 2062/2146 frames processed in VID111
#
# Processing frame: 002062
# Completed frame 002062 - Found 1 detections
# Progress: 2063/2146 frames processed in VID111
#
# Processing frame: 002063
# Completed frame 002063 - Found 1 detections
# Progress: 2064/2146 frames processed in VID111
#
# Processing frame: 002064
# Completed frame 002064 - Found 1 detections
# Progress: 2065/2146 frames processed in VID111
#
# Processing frame: 002065
# Completed frame 002065 - Found 1 detections
# Progress: 2066/2146 frames processed in VID111
#
# Processing frame: 002066
# Completed frame 002066 - Found 1 detections
# Progress: 2067/2146 frames processed in VID111
#
# Processing frame: 002067
# Completed frame 002067 - Found 1 detections
# Progress: 2068/2146 frames processed in VID111
#
# Processing frame: 002068
# Completed frame 002068 - Found 1 detections
# Progress: 2069/2146 frames processed in VID111
#
# Processing frame: 002069
# Completed frame 002069 - Found 1 detections
# Progress: 2070/2146 frames processed in VID111
#
# Processing frame: 002070
# Completed frame 002070 - Found 1 detections
# Progress: 2071/2146 frames processed in VID111
#
# Processing frame: 002071
# Completed frame 002071 - Found 1 detections
# Progress: 2072/2146 frames processed in VID111
#
# Processing frame: 002072
# Completed frame 002072 - Found 1 detections
# Progress: 2073/2146 frames processed in VID111
#
# Processing frame: 002073
# Completed frame 002073 - Found 1 detections
# Progress: 2074/2146 frames processed in VID111
#
# Processing frame: 002074
# Completed frame 002074 - Found 1 detections
# Progress: 2075/2146 frames processed in VID111
#
# Processing frame: 002075
# Completed frame 002075 - Found 1 detections
# Progress: 2076/2146 frames processed in VID111
#
# Processing frame: 002076
# Completed frame 002076 - Found 1 detections
# Progress: 2077/2146 frames processed in VID111
#
# Processing frame: 002077
# Completed frame 002077 - Found 1 detections
# Progress: 2078/2146 frames processed in VID111
#
# Processing frame: 002078
# Completed frame 002078 - Found 1 detections
# Progress: 2079/2146 frames processed in VID111
#
# Processing frame: 002079
# Completed frame 002079 - Found 1 detections
# Progress: 2080/2146 frames processed in VID111
#
# Processing frame: 002080
# Completed frame 002080 - Found 1 detections
# Progress: 2081/2146 frames processed in VID111
#
# Processing frame: 002081
# Completed frame 002081 - Found 1 detections
# Progress: 2082/2146 frames processed in VID111
#
# Processing frame: 002082
# Completed frame 002082 - Found 1 detections
# Progress: 2083/2146 frames processed in VID111
#
# Processing frame: 002083
# Completed frame 002083 - Found 1 detections
# Progress: 2084/2146 frames processed in VID111
#
# Processing frame: 002084
# Completed frame 002084 - Found 1 detections
# Progress: 2085/2146 frames processed in VID111
#
# Processing frame: 002085
# Completed frame 002085 - Found 1 detections
# Progress: 2086/2146 frames processed in VID111
#
# Processing frame: 002086
# Completed frame 002086 - Found 1 detections
# Progress: 2087/2146 frames processed in VID111
#
# Processing frame: 002087
# Completed frame 002087 - Found 1 detections
# Progress: 2088/2146 frames processed in VID111
#
# Processing frame: 002088
# Completed frame 002088 - Found 1 detections
# Progress: 2089/2146 frames processed in VID111
#
# Processing frame: 002089
# Completed frame 002089 - Found 1 detections
# Progress: 2090/2146 frames processed in VID111
#
# Processing frame: 002090
# Completed frame 002090 - Found 1 detections
# Progress: 2091/2146 frames processed in VID111
#
# Processing frame: 002091
# Completed frame 002091 - Found 1 detections
# Progress: 2092/2146 frames processed in VID111
#
# Processing frame: 002092
# Completed frame 002092 - Found 1 detections
# Progress: 2093/2146 frames processed in VID111
#
# Processing frame: 002093
# Completed frame 002093 - Found 1 detections
# Progress: 2094/2146 frames processed in VID111
#
# Processing frame: 002094
# Completed frame 002094 - Found 1 detections
# Progress: 2095/2146 frames processed in VID111
#
# Processing frame: 002095
# Completed frame 002095 - Found 1 detections
# Progress: 2096/2146 frames processed in VID111
#
# Processing frame: 002096
# Completed frame 002096 - Found 1 detections
# Progress: 2097/2146 frames processed in VID111
#
# Processing frame: 002097
# Completed frame 002097 - Found 1 detections
# Progress: 2098/2146 frames processed in VID111
#
# Processing frame: 002098
# Completed frame 002098 - Found 1 detections
# Progress: 2099/2146 frames processed in VID111
#
# Processing frame: 002099
# Completed frame 002099 - Found 1 detections
# Progress: 2100/2146 frames processed in VID111
#
# Processing frame: 002100
# Completed frame 002100 - Found 1 detections
# Progress: 2101/2146 frames processed in VID111
#
# Processing frame: 002101
# Completed frame 002101 - Found 1 detections
# Progress: 2102/2146 frames processed in VID111
#
# Processing frame: 002102
# Completed frame 002102 - Found 1 detections
# Progress: 2103/2146 frames processed in VID111
#
# Processing frame: 002103
# Completed frame 002103 - Found 1 detections
# Progress: 2104/2146 frames processed in VID111
#
# Processing frame: 002104
# Completed frame 002104 - Found 1 detections
# Progress: 2105/2146 frames processed in VID111
#
# Processing frame: 002105
# Completed frame 002105 - Found 1 detections
# Progress: 2106/2146 frames processed in VID111
#
# Processing frame: 002106
# Completed frame 002106 - Found 1 detections
# Progress: 2107/2146 frames processed in VID111
#
# Processing frame: 002107
# Completed frame 002107 - Found 1 detections
# Progress: 2108/2146 frames processed in VID111
#
# Processing frame: 002108
# Completed frame 002108 - Found 1 detections
# Progress: 2109/2146 frames processed in VID111
#
# Processing frame: 002109
# Completed frame 002109 - Found 1 detections
# Progress: 2110/2146 frames processed in VID111
#
# Processing frame: 002110
# Completed frame 002110 - Found 1 detections
# Progress: 2111/2146 frames processed in VID111
#
# Processing frame: 002111
# Completed frame 002111 - Found 1 detections
# Progress: 2112/2146 frames processed in VID111
#
# Processing frame: 002112
# Completed frame 002112 - Found 1 detections
# Progress: 2113/2146 frames processed in VID111
#
# Processing frame: 002113
# Completed frame 002113 - Found 1 detections
# Progress: 2114/2146 frames processed in VID111
#
# Processing frame: 002114
# Completed frame 002114 - Found 1 detections
# Progress: 2115/2146 frames processed in VID111
#
# Processing frame: 002115
# Completed frame 002115 - Found 1 detections
# Progress: 2116/2146 frames processed in VID111
#
# Processing frame: 002116
# Completed frame 002116 - Found 1 detections
# Progress: 2117/2146 frames processed in VID111
#
# Processing frame: 002117
# Completed frame 002117 - Found 1 detections
# Progress: 2118/2146 frames processed in VID111
#
# Processing frame: 002118
# Completed frame 002118 - Found 1 detections
# Progress: 2119/2146 frames processed in VID111
#
# Processing frame: 002119
# Completed frame 002119 - Found 1 detections
# Progress: 2120/2146 frames processed in VID111
#
# Processing frame: 002120
# Completed frame 002120 - Found 1 detections
# Progress: 2121/2146 frames processed in VID111
#
# Processing frame: 002121
# Completed frame 002121 - Found 1 detections
# Progress: 2122/2146 frames processed in VID111
#
# Processing frame: 002122
# Completed frame 002122 - Found 1 detections
# Progress: 2123/2146 frames processed in VID111
#
# Processing frame: 002123
# Completed frame 002123 - Found 1 detections
# Progress: 2124/2146 frames processed in VID111
#
# Processing frame: 002124
# Completed frame 002124 - Found 1 detections
# Progress: 2125/2146 frames processed in VID111
#
# Processing frame: 002125
# Completed frame 002125 - Found 1 detections
# Progress: 2126/2146 frames processed in VID111
#
# Processing frame: 002126
# Completed frame 002126 - Found 1 detections
# Progress: 2127/2146 frames processed in VID111
#
# Processing frame: 002127
# Completed frame 002127 - Found 1 detections
# Progress: 2128/2146 frames processed in VID111
#
# Processing frame: 002128
# Completed frame 002128 - Found 1 detections
# Progress: 2129/2146 frames processed in VID111
#
# Processing frame: 002129
# Completed frame 002129 - Found 1 detections
# Progress: 2130/2146 frames processed in VID111
#
# Processing frame: 002130
# Completed frame 002130 - Found 1 detections
# Progress: 2131/2146 frames processed in VID111
#
# Processing frame: 002131
# Completed frame 002131 - Found 1 detections
# Progress: 2132/2146 frames processed in VID111
#
# Processing frame: 002132
# Completed frame 002132 - Found 1 detections
# Progress: 2133/2146 frames processed in VID111
#
# Processing frame: 002133
# Completed frame 002133 - Found 1 detections
# Progress: 2134/2146 frames processed in VID111
#
# Processing frame: 002134
# Completed frame 002134 - Found 1 detections
# Progress: 2135/2146 frames processed in VID111
#
# Processing frame: 002135
# Completed frame 002135 - Found 1 detections
# Progress: 2136/2146 frames processed in VID111
#
# Processing frame: 002136
# Completed frame 002136 - Found 1 detections
# Progress: 2137/2146 frames processed in VID111
#
# Processing frame: 002137
# Completed frame 002137 - Found 1 detections
# Progress: 2138/2146 frames processed in VID111
#
# Processing frame: 002138
# Completed frame 002138 - Found 1 detections
# Progress: 2139/2146 frames processed in VID111
#
# Processing frame: 002139
# Completed frame 002139 - Found 1 detections
# Progress: 2140/2146 frames processed in VID111
#
# Processing frame: 002140
# Completed frame 002140 - Found 1 detections
# Progress: 2141/2146 frames processed in VID111
#
# Processing frame: 002141
# Completed frame 002141 - Found 1 detections
# Progress: 2142/2146 frames processed in VID111
#
# Processing frame: 002142
# Completed frame 002142 - Found 1 detections
# Progress: 2143/2146 frames processed in VID111
#
# Processing frame: 002143
# Completed frame 002143 - Found 1 detections
# Progress: 2144/2146 frames processed in VID111
#
# Processing frame: 002144
# Completed frame 002144 - Found 1 detections
# Progress: 2145/2146 frames processed in VID111
#
# Processing frame: 002145
# Completed frame 002145 - Found 1 detections
# Progress: 2146/2146 frames processed in VID111
#
# Processing complete! Results saved to: /content/CholecT50/videos/all_video_predictions.json

# %%
import json

def convert_frame_ids(filepath):
    # Read the existing JSON file
    with open(filepath, 'r') as f:
        data = json.load(f)

    # Create new dictionary with converted frame IDs
    converted_data = {}
    for video_id, frames in data.items():
        converted_data[video_id] = {}
        for frame_id, content in frames.items():
            # Convert frame_id from string to integer, handle empty string
            new_frame_id = int(frame_id.lstrip('0')) if frame_id.lstrip('0') else 0
            converted_data[video_id][new_frame_id] = content

    # Save the converted JSON back to file
    with open(filepath, 'w') as f:
        json.dump(converted_data, f)

    print("Frame IDs have been converted to integers successfully!")

# Run the conversion
filepath = "/content/all_video_predictions.json"
convert_frame_ids(filepath)
# Out:
# Frame IDs have been converted to integers successfully!
